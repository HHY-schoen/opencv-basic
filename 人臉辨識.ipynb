# %% [markdown]
# - opencv github 上有非常多已經訓練好的模型可以做使用。
# - https://github.com/opencv/opencv/tree/4.x/data/haarcascades

# %%
import cv2
from google.colab.patches import cv2

img = cv2.imread('lenna.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faceCascade = cv2.CascadeClassifier('face_detect.xml')  #載入模型
faceRect = faceCascade.detectMultiScale(gray, 1.1, 3)  #辨識人臉 (圖,每次縮小倍數,臉要被偵測到幾次)
print(len(faceRect))

for (x, y, w, h) in faceRect:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2_imshow(img)
# Out:
# 1
# <PIL.Image.Image image mode=RGB size=316x316>

# %%
import cv2
from google.colab.patches import cv2

img = cv2.imread('qq.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faceCascade = cv2.CascadeClassifier('face_detect.xml')  #載入模型
faceRect = faceCascade.detectMultiScale(gray, 1.1, 5)  #辨識人臉 (圖,每次縮小倍數,臉要被偵測到幾次)
print(len(faceRect))

for (x, y, w, h) in faceRect:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

cv2_imshow(img)
# Out:
# 3
# <PIL.Image.Image image mode=RGB size=600x781>
